# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
import sys
sys.path.append("/workspaces/remember-me/api/src")

# %%
import requests

# %%
response
# Out:
# <Response [500]>

# %%
image_id = 7
response = requests.get(f"http://127.0.0.1:8000/image/{image_id}/create")

# %%
response.json()
# Out:
# {'audio_url': '/workspaces/remember-me/api/var/event2.mp3'}

# %%
person_id = 1
response = requests.get(f"http://127.0.0.1:8000/person/{person_id}/create")

# %%
response.json()
# Out:
# {'audio_url': 'person1.mp3'}
